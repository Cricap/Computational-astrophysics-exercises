# %% [markdown]
# ## Exercise - Cosmological Parameters From Type Ia Supernova Data
#
# In this exercise we will work with some type Ia supernova data.  This is part of the data used to determine that Universe's expansion is accelerating.
#
# Data obtained is from the Supernova Cosmology Project at:
# http://supernova.lbl.gov/union/descriptions.html#Magvsz
#
# **Background:**
#
# The observed magnitude of an object with luminosity $L$ is
#
# $m = - 2.5 \log\left( \frac{L}{2\pi D_L^2} \right) + m_o = 5 \log\left( D_L \right) + 2.5 \log\left( L \right) + m_o$
#
# where $D_L$ is the luminosity distance and $m_o$ is the zero point, a constant.  The peak luminosity of a type Ia supernovae
# is directly related to the width of its lightcurve and its color.  In this data set, the correction to a standard candle has already been done by fitting light curves (see previous example).  In the data the corrected apparent magnitude is reported in terms of the estimated distance modulus
#
# $\mu = 5 \log\left( D_L \right) - \mu_o$
#
# This assumes a Hubble constant ($D_L \propto 1/H_o$) and requires a calibration using other distance indicators in local galaxies so there is an additive constant in the distance modulus (or a multiplicative constant to the brightness) that is not very well constrained, i.e. the relative magnitudes of the supernovae are well measured, but not their absolute brightnesses.
#
# General relativity and the energy content of the Universe predicts a function for $D_L(z)$ (or $\mu(z)$) where $z$ is the cosmological redshift of the supernovae.  The relation depends on the density of the universe in matter $\Omega_{matter}$ and the energy density of the cosmological constant $\Omega_{\Lambda}$.  Both are in units of the critical density and must be greater than or equal to 0 and less than or equal to 1.
#
# In this tutorial we will make and test some models for $\mu(z)$.  It will be assumed that the redshifts are very well measured so that their errors do not need to be taken into account (We will also ignore peculiar velocities.) and that the errors in the measured $\mu(z)$'s are normally distributed.

# %% [markdown]
# 1) Import the data using the command.
#
# `data = pa.read_csv("SCPUnion2.1_mu_vs_z.txt",sep='\t',comment='#')`
#
# Note that there are comments starting with
# "#" and the seporators are tabs not commas.
#
# Plot the distance modulus vs redshift with error bars and no line connecting the points.  Label the axes.

# %%
import numpy as np
import pandas as pa
import matplotlib.pyplot as plt

data = pa.read_csv("SCPUnion2.1_mu_vs_z.txt",sep='\t',comment='#')

#data.info()

z = data['redshift']
mu = data['dist_mod']
errors = data['dist_mod_error']
plt.errorbar(z,mu,errors, ls='none',fmt='--',capsize=2,elinewidth=0.5)

plt.title('')
plt.ylabel(r'$\mu$')
plt.xlabel('Z')
plt.show()
# Out:
# /tmp/ipykernel_4896/2641998769.py:12: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "--" (-> linestyle='--'). The keyword argument will take precedence.
#   plt.errorbar(z,mu,errors, ls='none',fmt='--',capsize=2,elinewidth=0.5)

# %% [markdown]
# 2) Write a function that takes redshift, $\mu_o$, $\Omega_m$, $\Omega_\Lambda$ and returns $\mu(z)$.
# Use the library function astropy.cosmology.LambdaCDM.luminosity_distance(z).value
# to calculate the luminosity distance. The Hubble parameter is not separable from $\mu_o$ so just use $H_o = 70$ in this function.
#
# The function should take all the parameters as if they are in a python dictionary.  For example `p['Omega_matter']` for $\Omega_{matter}$.
#
# The parameters p should be :
#
# `p['mu_o']` is the absolute magnitude normalization, $\mu_o$
#
# `p['Omega_matter']` is $\Omega_{matter}$.
#
# `p['Omega_lambda']` is $\Omega_\Lambda$.
#
# This is a nonlinear function of the $\Omega$'s and a linear function of $\mu_o$.

# %%
from scipy.optimize import curve_fit
import astropy.cosmology as cosmo
import numpy as np

def mu_function(redshift,p) :
    cosmology = cosmo.LambdaCDM(70,p['Omega_matter'].value, p['Omega_lambda'].value)
    dl = cosmology.luminosity_distance(redshift).to_value()

    return 5*np.log10(dl)+p['mu_o'].value

# %% [markdown]
# 3) Write a function that calculates $\chi^2$ given the data.  It should be a function of `p` only.  Your `mu_function()` should be used inside it.

# %%
mu_model = np.zeros_like(z)
def my_chi2(p) :
    mu_model = mu_function(z,p)
    return np.sum((mu-mu_model)**2/errors**2)

# %% [markdown]
# There are a number of library functions available to minimize functions including `scipy.optimize.minimize` (which we used in the last exercise) and `scipy.optimize.curve_fit`.  Here we will use a powerful library [`lmfit`](https://lmfit.github.io/lmfit-py/fitting.html#minimizerresult-the-optimization-result) because it will allow us to easily minimize the function while keeping some parameters constant without having to re-write our $\chi^2$ function.  You might have to install this library with `pip install lmfit`.
#
# For this library the the parameters are defined in a tuple of tuples and used like a dictionary.  Each parameter has a name (the same one you used to call it above), an intial value, a boolian flag that determines if that parameter will be varied when optimizing, and then two numbers giving the allowed range.
#
# Here is an example:

# %%
# pip install lmfit
import lmfit

p = lmfit.Parameters()
p.add_many(('Omega_matter',1.0,True,0,1)
           ,('Omega_lambda',0.0,True,0,1)
           ,('mu_o',24.9,True,10,30))

# %% [markdown]
# 4) Use `lmfit.minimize` and the $\chi^2$ function you wrote above to find the $\mu_o$
# $\Omega_m$ and $\Omega_\Lambda$ that minimize the $\chi^2$.  Print the best fit parameter values.
# Use `method='Nelder'` in `lmfit.minimize`.  Look at the structure it returns to understand how to access the parameter values.

# %%
best_fit_result = lmfit.minimize(my_chi2,p,method='Nelder')
lmfit.printfuncs.report_fit(best_fit_result.params)

## here is how to access the results of the minimization
print('best fit value for Omega_matter ', best_fit_result.params['Omega_matter'].value)
print('best fit value for Omega_Lambda ',best_fit_result.params['Omega_lambda'].value)
print('best fit chi2 :',my_chi2(best_fit_result.params))
# Out:
# [[Variables]]
#     Omega_matter:  0.27914985 (init = 1)
#     Omega_lambda:  0.72503222 (init = 0)
#     mu_o:          24.9997301 (init = 24.9)
# best fit value for Omega_matter  0.2791498539264884
# best fit value for Omega_Lambda  0.725032221942054
# best fit chi2 : 562.2261096075133

# %% [markdown]
# 5) Plot the best fit model over the data as already plotted using the functions already defined.

# %%
zz = np.arange(0.01,1.5,0.01)
m = mu_function(zz, best_fit_result.params)

plt.plot(zz, m)
plt.errorbar(z,mu,errors, ls='none',fmt='--',capsize=2,elinewidth=0.5)
plt.ylabel(r'$\mu$')
plt.xlabel('Z')
plt.show()
# Out:
# /tmp/ipykernel_4896/1218140237.py:5: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "--" (-> linestyle='--'). The keyword argument will take precedence.
#   plt.errorbar(z,mu,errors, ls='none',fmt='--',capsize=2,elinewidth=0.5)

# %% [markdown]
# 6) At the best fit parameter values, give the p-value and confidence level.

# %%
from scipy.stats import chi2
chisq=my_chi2(best_fit_result.params)
print('chi-squared = ', chisq )
print('confidence level = ', chi2.cdf(chisq, len(mu)-2))
print('p-value = ',chi2.sf(chisq, len(mu)-2))
# Out:
# chi-squared =  562.2261096075133
# confidence level =  0.32687008476670487
# p-value =  0.6731299152332951

# %% [markdown]
# 7) Now assume that $\Omega_\Lambda = 0$ (no cosmological constant).  What is the best fit $\Omega_m$ and $m_o$ in this case?

# %%
p['Omega_lambda'].set(value=0.0, vary=False)
best_fit_result1 = lmfit.minimize(my_chi2,p,method='Nelder')
lmfit.printfuncs.report_fit(best_fit_result1.params)
chisq1=my_chi2(best_fit_result1.params)
print('------------------------------------------------')
print('best fit chi2 :',chisq1)
print('confidence level = ',chi2.cdf(chisq1, len(mu)-2))
print('p-value = ',chi2.sf(chisq1, len(mu)-2))
# Out:
# [[Variables]]
#     Omega_matter:  1.9838e-10 (init = 1)
#     Omega_lambda:  0 (fixed)
#     mu_o:          25.0779147 (init = 24.9)
# ------------------------------------------------
# best fit chi2 : 603.3779009708707
# confidence level =  0.7749640159899119
# p-value =  0.2250359840100881

# %% [markdown]
# 8) Plot in 2 dimensions ($\Omega_m$ vs $\mu_o$) the 68%, 95% and 99% confidence regions. (Hint: this will involve creating a new parameter set for each point in the 2D $\Omega_m$ - $\mu_o$ and using `lmfit.minimize`.  You also might want to use `method='powell'`)  This may take a little while to run.

# %%
n = 2

cl68 = chi2.ppf(.68, len(mu))
cl95 = chi2.ppf(.95, len(mu))
cl99 = chi2.ppf(.99, len(mu))

print(cl68/n,cl95/n,cl99/n)

mus=np.linspace(24.8,25.2,20)
omegas=np.linspace(0.01,1.0,20)
x2d,y2d = np.meshgrid(mus,omegas)

print(len(mus))
print(len(omegas))
print(x2d.shape)
p['Omega_lambda'].set(value=0.0, vary=True)
X2 = np.zeros(x2d.shape)
for i in range(0,len(mus)) :
    p['mu_o'].set(value=mus[i], vary=False)
    for j in range(0,len(omegas)) :
        p['Omega_matter'].set(value=omegas[j], vary=False)
        best_fit_result2= lmfit.minimize(my_chi2,p,method='powell')
        
        chisquared=my_chi2(best_fit_result2.params)
        X2[j,i] = chisquared

fig, ax = plt.subplots()
CS = ax.contour(x2d,y2d,X2,levels=[cl68,cl95,cl99])
## the stupidly complicated way contours are labeled 
fmt = {}
strs = [ '68%', '95%', '99%']
for i,s in zip( CS.levels, strs ):
    fmt[i] = s

ax.clabel(CS, inline=True, fontsize=10,fmt=fmt)

plt.xlabel(r'$\mu_o$')
plt.ylabel(r'$\Omega_m$')
plt.show()
# Out:
# 297.69909102906036 318.5677369009205 331.0804289417083
# 20
# 20
# (20, 20)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[85], line 22
#      20 for j in range(0,len(omegas)) :
#      21     p['Omega_matter'].set(value=omegas[j], vary=False)
# ---> 22     best_fit_result2= lmfit.minimize(my_chi2,p,method='powell')
#      24     chisquared=my_chi2(best_fit_result2.params)
#      25     X2[j,i] = chisquared
#
# File ~/.local/lib/python3.10/site-packages/lmfit/minimizer.py:2601, in minimize(fcn, params, method, args, kws, iter_cb, scale_covar, nan_policy, reduce_fcn, calc_covar, max_nfev, **fit_kws)
#    2461 """Perform the minimization of the objective function.
#    2462
#    2463 The minimize function takes an objective function to be minimized,
#    (...)
#    2595
#    2596 """
#    2597 fitter = Minimizer(fcn, params, fcn_args=args, fcn_kws=kws,
#    2598                    iter_cb=iter_cb, scale_covar=scale_covar,
#    2599                    nan_policy=nan_policy, reduce_fcn=reduce_fcn,
#    2600                    calc_covar=calc_covar, max_nfev=max_nfev, **fit_kws)
# -> 2601 return fitter.minimize(method=method)
#
# File ~/.local/lib/python3.10/site-packages/lmfit/minimizer.py:2345, in Minimizer.minimize(self, method, params, **kws)
#    2342         if (key.lower().startswith(user_method) or
#    2343                 val.lower().startswith(user_method)):
#    2344             kwargs['method'] = val
# -> 2345 return function(**kwargs)
#
# File ~/.local/lib/python3.10/site-packages/lmfit/minimizer.py:979, in Minimizer.scalar_minimize(self, method, params, max_nfev, **kws)
#     977 result.call_kws = fmin_kws
#     978 try:
# --> 979     ret = scipy_minimize(self.penalty, variables, **fmin_kws)
#     980 except AbortFitException:
#     981     pass
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_minimize.py:701, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     698     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     699                                **options)
#     700 elif meth == 'powell':
# --> 701     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#     702 elif meth == 'cg':
#     703     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_optimize.py:3507, in _minimize_powell(func, x0, args, callback, bounds, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    3505 direc1 = direc[i]
#    3506 fx2 = fval
# -> 3507 fval, x, direc1 = _linesearch_powell(func, x, direc1,
#    3508                                      tol=xtol * 100,
#    3509                                      lower_bound=lower_bound,
#    3510                                      upper_bound=upper_bound,
#    3511                                      fval=fval)
#    3512 if (fx2 - fval) > delta:
#    3513     delta = fx2 - fval
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_optimize.py:3183, in _linesearch_powell(func, p, xi, tol, lower_bound, upper_bound, fval)
#    3180     return ((fval, p, xi) if fval is not None else (func(p), p, xi))
#    3181 elif lower_bound is None and upper_bound is None:
#    3182     # non-bounded minimization
# -> 3183     res = _recover_from_bracket_error(_minimize_scalar_brent,
#    3184                                       myfunc, None, tuple(), xtol=tol)
#    3185     alpha_min, fret = res.x, res.fun
#    3186     xi = alpha_min * xi
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_optimize.py:3076, in _recover_from_bracket_error(solver, fun, bracket, args, **options)
#    3057 def _recover_from_bracket_error(solver, fun, bracket, args, **options):
#    3058     # `bracket` was originally written without checking whether the resulting
#    3059     # bracket is valid. `brent` and `golden` built on top of it without
#    (...)
#    3073     # storing the information needed by `minimize_scalar` in the error object,
#    3074     # and intercepting it here.
#    3075     try:
# -> 3076         res = solver(fun, bracket, args, **options)
#    3077     except BracketError as e:
#    3078         msg = str(e)
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_optimize.py:2679, in _minimize_scalar_brent(func, brack, args, xtol, maxiter, disp, **unknown_options)
#    2676 brent = Brent(func=func, args=args, tol=tol,
#    2677               full_output=True, maxiter=maxiter, disp=disp)
#    2678 brent.set_bracket(brack)
# -> 2679 brent.optimize()
#    2680 x, fval, nit, nfev = brent.get_result(full_output=True)
#    2682 success = nit < maxiter and not (np.isnan(x) or np.isnan(fval))
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_optimize.py:2521, in Brent.optimize(self)
#    2519 else:
#    2520     u = x + rat
# -> 2521 fu = func(*((u,) + self.args))      # calculate new output value
#    2522 funcalls += 1
#    2524 if (fu > fx):                 # if it's bigger than current
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_optimize.py:3176, in _linesearch_powell.<locals>.myfunc(alpha)
#    3175 def myfunc(alpha):
# -> 3176     return func(p + alpha*xi)
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_optimize.py:620, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     618 ncalls[0] += 1
#     619 # A copy of x is sent to the user function (gh13740)
# --> 620 fx = function(np.copy(x), *(wrapper_args + args))
#     621 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     622 # backwards-compatibility, also allow np.array([1.3]),
#     623 # np.array([[1.3]]) etc.
#     624 if not np.isscalar(fx):
#
# File ~/.local/lib/python3.10/site-packages/lmfit/minimizer.py:615, in Minimizer.penalty(self, fvars)
#     612 else:
#     613     apply_bounds_transformation = True
# --> 615 r = self.__residual(fvars, apply_bounds_transformation)
#     616 if isinstance(r, np.ndarray) and r.size > 1:
#     617     r = self.reduce_fcn(r)
#
# File ~/.local/lib/python3.10/site-packages/lmfit/minimizer.py:548, in Minimizer.__residual(self, fvars, apply_bounds_transformation)
#     545     self.result.success = False
#     546     raise AbortFitException(f"fit aborted: too many function evaluations {self.max_nfev}")
# --> 548 out = self.userfcn(params, *self.userargs, **self.userkws)
#     550 if callable(self.iter_cb):
#     551     abort = self.iter_cb(params, self.result.nfev, out,
#     552                          *self.userargs, **self.userkws)
#
# Cell In[73], line 3, in my_chi2(p)
#       2 def my_chi2(p) :
# ----> 3     mu_model = mu_function(z,p)
#       4     return np.sum((mu-mu_model)**2/errors**2)
#
# Cell In[72], line 6, in mu_function(redshift, p)
#       5 def mu_function(redshift,p) :
# ----> 6     cosmology = cosmo.LambdaCDM(70,p['Omega_matter'].value, p['Omega_lambda'].value)
#       7     dl = cosmology.luminosity_distance(redshift).to_value()
#       9     return 5*np.log10(dl)+p['mu_o'].value
#
# File ~/.local/lib/python3.10/site-packages/astropy/cosmology/flrw/lambdacdm.py:103, in LambdaCDM.__init__(self, H0, Om0, Ode0, Tcmb0, Neff, m_nu, Ob0, name, meta)
#      90 def __init__(
#      91     self,
#      92     H0,
#    (...)
#     101     meta=None,
#     102 ):
# --> 103     super().__init__(
#     104         H0=H0,
#     105         Om0=Om0,
#     106         Ode0=Ode0,
#     107         Tcmb0=Tcmb0,
#     108         Neff=Neff,
#     109         m_nu=m_nu,
#     110         Ob0=Ob0,
#     111         name=name,
#     112         meta=meta,
#     113     )
#     115     # Please see :ref:`astropy-cosmology-fast-integrals` for discussion
#     116     # about what is being done here.
#     117     if self._Tcmb0.value == 0:
#
# File ~/.local/lib/python3.10/site-packages/astropy/cosmology/flrw/base.py:210, in FLRW.__init__(self, H0, Om0, Ode0, Tcmb0, Neff, m_nu, Ob0, name, meta)
#     207 super().__init__(name=name, meta=meta)
#     209 # Assign (and validate) Parameters
# --> 210 self.H0 = H0
#     211 self.Om0 = Om0
#     212 self.Ode0 = Ode0
#
# File ~/.local/lib/python3.10/site-packages/astropy/cosmology/parameter/_core.py:217, in Parameter.__set__(self, cosmology, value)
#     214     value = self.default
#     216 # Validate value, generally setting units if present
# --> 217 value = self.validate(cosmology, copy.deepcopy(value))
#     219 # Make the value read-only, if ndarray-like
#     220 if hasattr(value, "setflags"):
#
# File ~/.local/lib/python3.10/site-packages/astropy/cosmology/parameter/_core.py:260, in Parameter.validate(self, cosmology, value)
#     245 def validate(self, cosmology, value):
#     246     """Run the validator on this Parameter.
#     247
#     248     Parameters
#    (...)
#     258         (yes, that parameter order).
#     259     """
# --> 260     return self._fvalidate(cosmology, self, value)
#
# File ~/.local/lib/python3.10/site-packages/astropy/cosmology/parameter/_converter.py:83, in _validate_to_scalar(cosmology, param, value)
#      80 @_register_validator("scalar")
#      81 def _validate_to_scalar(cosmology, param, value):
#      82     """"""
# ---> 83     value = _validate_with_unit(cosmology, param, value)
#      84     if not value.isscalar:
#      85         raise ValueError(f"{param.name} is a non-scalar quantity")
#
# File ~/.local/lib/python3.10/site-packages/astropy/cosmology/parameter/_converter.py:68, in _validate_with_unit(cosmology, param, value)
#      63 """Default Parameter value validator.
#      64
#      65 Adds/converts units if Parameter has a unit.
#      66 """
#      67 if param.unit is not None:
# ---> 68     with u.add_enabled_equivalencies(param.equivalencies):
#      69         value = u.Quantity(value, param.unit)
#      70 return value
#
# File ~/.local/lib/python3.10/site-packages/astropy/units/core.py:524, in add_enabled_equivalencies(equivalencies)
#     507 """
#     508 Adds to the equivalencies enabled in the unit registry.
#     509
#    (...)
#     521     `~astropy.units.equivalencies.dimensionless_angles`.
#     522 """
#     523 # get a context with a new registry, which is a copy of the current one
# --> 524 context = _UnitContext(get_current_unit_registry())
#     525 # in this new current registry, enable the further equivalencies requested
#     526 get_current_unit_registry().add_enabled_equivalencies(equivalencies)
#
# File ~/.local/lib/python3.10/site-packages/astropy/units/core.py:350, in _UnitContext.__init__(self, init, equivalencies)
#     349 def __init__(self, init=[], equivalencies=[]):
# --> 350     _unit_registries.append(_UnitRegistry(init=init, equivalencies=equivalencies))
#
# File ~/.local/lib/python3.10/site-packages/astropy/units/core.py:138, in _UnitRegistry.__init__(self, init, equivalencies, aliases)
#     136 self._equivalencies = init._equivalencies.copy()
#     137 self._aliases = init._aliases.copy()
# --> 138 self._all_units = init._all_units.copy()
#     139 self._registry = init._registry.copy()
#     140 self._non_prefix_units = init._non_prefix_units.copy()
#
# KeyboardInterrupt:

# %% [markdown]
# 9) Do the same, but for a confidence level plot in the $\Omega_\Lambda$ - $\Omega_m$ plane.  You can reuse a lot of the code from the previous cell.

# %%
omega_m=np.arange(0.01,1.0,0.04)
omega_l=np.arange(0.01,1.0,0.04)
x2d,y2d = np.meshgrid(omega_m,omega_l)

X2 = np.zeros(x2d.shape)

....
....

plt.ylabel(r'$\Omega_\Lambda$')
plt.xlabel(r'$\Omega_m$')
plt.show()
# Out:
#   Cell In[80], line 7
#     ....
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# 10) We want to find the 68%, 95% and 99% confidence regions for $\Omega_\Lambda$ alone.  First plot $\chi^2$ as a function of $\Omega_\Lambda$ alone.  Put some horizontal dotted lines at
# the $\chi^2$ values for the three confidence levels.

# %%
omega_m=np.arange(0.0,1.0,0.02)
X2 = np.zeros(len(omega_m))
for i in range(0,len(omega_m)) :
    ...
    ...

    X2[i] = ...


plt.plot(omega_m,X2)

plt.plot([0,1.0], ... ,linestyle=':',label=r'68% cl')
plt.plot([0,1.0], ... ,linestyle=':',label=r'95% cl')
plt.plot([0,1.0], ... ,linestyle=':',label=r'99% cl')
plt.xlim(0,1)
plt.xlabel(r'$\Omega_m$')
plt.ylabel(r'$\chi^2$')
plt.legend()
plt.show()

# %% [markdown]
# 11) Now imagine that we know from some other observations that $\Omega_m=0.5$.  Make the same plot, but for $\Omega_\Lambda$ and $\Omega_m=0.5$.

# %%
...
...

plt.plot([0,1.0], ... ,linestyle=':',label=r'68% cl')
plt.plot([0,1.0], ... ,linestyle=':',label=r'95% cl')
plt.plot([0,1.0], ... ,linestyle=':',label=r'99% cl')
plt.xlim(0,1)
plt.xlabel(r'$\Omega_\Lambda$')
plt.ylabel(r'$\chi^2$')
plt.title(r'$\Omega_m=0.5$')
plt.legend()
plt.show()

# %% [markdown]
# 12) What are the 68%, 95% and 99% confidence regions for $\Omega_\Lambda$ *given that $\Omega_m=0.5$*?
#
# Taking into account that $0<\Omega_\Lambda<1$?  We can find these by finding the ranges in $\Omega_m$ where the $\chi^2$ vector created above is the limits (cl68, cl95, cl99)  found before.  (hint: I used numpy.argwhere() for this, but you can do it multiple ways.)

# %%
from scipy.interpolate import interp1d

...

print('68% confidence level : ', ... ,'< Omega_l <', ... )
index = np.argwhere(X2<cl95)
print('95% confidence level : ', ... ,'< Omega_l <', ... )
index = np.argwhere(X2<cl99)
print('99% confidence level : ', ... ,'< Omega_l <', ... )

# %% [markdown]
# 13) Let us experiment.  We hypothesize that there is an extra source of error in the standard candle correction procedure that was not taken into account.  The standard deviation of this error will be the parameter `p['extra_sig']`.  This error is statistically independent of the errors already given in the data file and normally distributed.  Find the maximum likelihood estimate for this extra parameter.  Minimizing the $\chi^2$ with respect to `p['extra_sig']` will not work in this case (why?).
#
# Write a function that returns the negative of the log of the likelihood ($-\ln(L)$).  It will be like the $\chi^2$ function you already wrote.  Minimize it with `lmfit.minimize()`.
#
# Is there a significant contribution from this extra source of noise?
# Would it change the best fit cosmological parameters?

# %%
def neg_lnL(p) :
    ...
    return ...

p = lmfit.Parameters()
p.add_many(...)            ### in magnitudes

best_fit_result = ...
lmfit.printfuncs.report_fit(best_fit_result.params)

# %% [markdown]
# **Double click on this and answer the questions:**
#
# Why can you not minimize the $\chi^2$ to find a good estimate for the extra noise?
#
# Is there a significant contribution from this extra source of noise?
#
# Would the existence of this extra noise change the best fit cosmological parameters?
